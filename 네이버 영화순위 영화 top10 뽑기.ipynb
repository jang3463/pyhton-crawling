# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84'

html = requests.get(url)

# %%
html.ok
# Out:
# True

# %%
html.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="영화순위 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'영화순위\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'영화순위\'의 네이버 통합검색 결과입니다."> <title>영화순위 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_201119.css"> <link rel="stylesheet" type="text/css
# ...

# %%
soup = BeautifulSoup(html.text, 'html.parser')

# %%
title = soup.find_all('strong', class_='name')

# %%
title
# Out:
# [<strong class="name">도굴</strong>,
#  <strong class="name">런</strong>,
#  <strong class="name">삼진그룹 영어토익반</strong>,
#  <strong class="name">내가 죽던 날</strong>,
#  <strong class="name">추억의 검정고무신</strong>,
#  <strong class="name">택스 콜렉터</strong>,
#  <strong class="name">극장판 바다 탐험대 옥토넛 ...</strong>,
#  <strong class="name">마리 퀴리</strong>,
#  <strong class="name">극장판 바이올렛 에버가든</strong>,
#  <strong class="name">킹덤 오브 헤븐: 디렉터스 컷</strong>,
#  <strong class="name">21 브릿지: 테러 셧다운</strong>,
#  <strong class="name">안티고네</strong>,
#  <strong class="name">노트북</strong>,
#  <strong class="name">요가학원:죽음의쿤달리니</strong>,
#  <strong class="name">애비규환</strong>,
#  <strong class="name">부활: 그 증거</strong>,
#  <strong class="name">테넷</strong>,
#  <strong class="name">피아니스트의 마지막 인터뷰</strong>,
#  <strong class="name">로미오와 줄리엣</strong>,
#  <strong class="name">봉쇄수도원 카르투시오</strong>,
#  <strong class="name">다윗과 밧세바</strong>,
#  <strong class="name">페이트 스테이 나이트 헤븐즈...</strong>,
#  <strong class="name">맹크</strong>,
# ...

# %%
title = [i.get_text().strip() for i in title[:10]]

# %%
title
# Out:
# ['도굴',
#  '런',
#  '삼진그룹 영어토익반',
#  '내가 죽던 날',
#  '추억의 검정고무신',
#  '택스 콜렉터',
#  '극장판 바다 탐험대 옥토넛 ...',
#  '마리 퀴리',
#  '극장판 바이올렛 에버가든',
#  '킹덤 오브 헤븐: 디렉터스 컷']
